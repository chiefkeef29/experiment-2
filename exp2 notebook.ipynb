# %%
#vedant mathur prn- 25070123120
# Exp2: Study of list in python
list1=["apple","orange","cherry"]
print(list1)
# Out:
# ['apple', 'orange', 'cherry']

# %%
list2=[2,2.5,'apple',True]
print(list2)
# Out:
# [2, 2.5, 'apple', True]

# %%
list3=["apple","banana","orange","cherry","kiwi","mango"]
print(list3[2])
print(list3[-4])
print(list3[2:5])
print(list3[:5])
print(list3[2:])
print(len(list3))
# Out:
# orange
# orange
# ['orange', 'cherry', 'kiwi']
# ['apple', 'banana', 'orange', 'cherry', 'kiwi']
# ['orange', 'cherry', 'kiwi', 'mango']
# 6

# %%
list4=["apple","orange","cherry"]
list4[1]="mango"
print(list4)
# Out:
# ['apple', 'mango', 'cherry']

# %%
list5=["apple","orange","cherry"]
list5.append("mango")
print(list5)
# Out:
# ['apple', 'orange', 'cherry', 'mango']

# %%
list6=["apple","orange","cherry"]
list6.insert(1,"mango")
print(list6)
# Out:
# ['apple', 'mango', 'orange', 'cherry']

# %%
list7=["apple,","orange","banana"]
list8=["cherry","kiwi","mango"]
list7.extend(list8)
print(list7)
# Out:
# ['apple,', 'orange', 'banana', 'cherry', 'kiwi', 'mango']

# %%
marks = [78,85,90,66,88]
print(max(marks))
print(min(marks))
print(sum(marks))
print(len(marks))
print(sum(marks)/len(marks))
# Out:
# 90
# 66
# 407
# 5
# 81.4

# %%
grocery = ["milk","flour","butter","rice flour","sugar"]
print(grocery)
# Out:
# ['milk', 'flour', 'butter', 'rice flour', 'sugar']

# %%
grocery.remove
print(grocery)
# Out:
# <function list.remove(value, /)>
